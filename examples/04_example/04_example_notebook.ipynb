# %% [markdown]
# Displaced and Distorted Harmonic Oscillator

# %%
import phlab
from  matplotlib import pyplot as plt

# %%
ws=phlab.rixs()

# %%
model1 = ws.model_single_osc(name = 'displaced osc')
model2 = ws.model_dist_disp_osc(name = 'distorted and displaced osc')
# Out:
# creating model : /Users/lusigeondzian/github/phlab/examples/04_example/displaced osc
# /Users/lusigeondzian/github/phlab/examples/04_example/displaced osc/_input/
# no input found
# creating new input
# warning : please check new input
# number of models : 1
# creating model : /Users/lusigeondzian/github/phlab/examples/04_example/distorted and displaced osc
# no input found
# creating new input
# warning : please check new input
# number of models : 2

# %%
model1.color = 'r'
model2.input['omega_ph_ex'] = 0.1
model2.color = 'b'

# %%
[model.run() for model in [model1,model2]]
# Out:
# [None, None]

# %%
plt.figure(figsize = (10,5))
vitem=ws.visual(model_list=[model1,model2],exp=[])
vitem.show(scale = 1)
# Out:
# no experiment in visual
