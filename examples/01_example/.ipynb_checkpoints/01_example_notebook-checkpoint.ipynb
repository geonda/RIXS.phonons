# %%
import phlab

# %%
workspace = phlab.rixs()

# %%
model1 = workspace.create_model()
# Out:
# done parsing input
# creating model
# number of models : 1

# %%
model1.input
model1.run()
# Out:
# nruns:1 coupling:0.15 omega:0.195
# ./_output/model_1/1_rixs_raw.csv

# %%
exp = workspace.creat_experiment(file = 'fake_exp.csv', name= ' test')

# %%
exp.max
# Out:
# 92.50262689135204

# %%
vitem = workspace.connect_visual(model_list = [model1], exp = exp)

# %%
vitem.show(scale = 0)
